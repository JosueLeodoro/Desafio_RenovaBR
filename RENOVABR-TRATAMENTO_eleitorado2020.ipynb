# %%
import pandas as pd

# %%
dados = pd.read_csv('perfil_eleitorado_2020/perfil_eleitorado_2020.csv', sep = ';')

# %%
dados.tail(100)
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 4248407  01/08/2020   08:37:48         2020    PR         74349
# 4248408  01/08/2020   08:37:48         2020    PR         74349
# 4248409  01/08/2020   08:37:48         2020    PR         74349
# 4248410  01/08/2020   08:37:48         2020    PR         74349
# 4248411  01/08/2020   08:37:48         2020    PR         74349
# ...             ...        ...          ...   ...           ...
# 4248502  01/08/2020   08:37:48         2020    PR         74349
# 4248503  01/08/2020   08:37:48         2020    PR         74349
# 4248504  01/08/2020   08:37:48         2020    PR         74349
# 4248505  01/08/2020   08:37:48         2020    PR         74349
# 4248506  01/08/2020   08:37:48         2020    PR         74349
#
#                  NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 4248407  FLOR DA SERRA DO SUL                     0        Sem biometria
# ...

# %%
estado = ['SP']

# %%
estado
# Out:
# ['SP']

# %%
selecao = dados['SG_UF'].isin(estado)

# %%
selecao.tail()
# Out:
# 4248502    False
# 4248503    False
# 4248504    False
# 4248505    False
# 4248506    False
# Name: SG_UF, dtype: bool

# %%
dados_sp = dados[selecao]

# %%
len(dados_sp)
# Out:
# 639502

# %%
len(dados)
# Out:
# 4248507

# %%
dados_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 639502 entries, 0 to 4248335
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   DT_GERACAO                  639502 non-null  object
#  1   HH_GERACAO                  639502 non-null  object
#  2   ANO_ELEICAO                 639502 non-null  int64
#  3   SG_UF                       639502 non-null  object
#  4   CD_MUNICIPIO                639502 non-null  int64
#  5   NM_MUNICIPIO                639502 non-null  object
#  6   CD_MUN_SIT_BIOMETRIA        639502 non-null  int64
#  7   DS_MUN_SIT_BIOMETRIA        639502 non-null  object
#  8   NR_ZONA                     639502 non-null  int64
#  9   CD_GENERO                   639502 non-null  int64
#  10  DS_GENERO                   639502 non-null  object
#  11  CD_ESTADO_CIVIL             639502 non-null  int64
#  12  DS_ESTADO_CIVIL             639502 non-null  object
# ...

# %%
dados_sp
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 0        01/08/2020   08:37:48         2020    SP         70734
# 1        01/08/2020   08:37:48         2020    SP         70734
# 2        01/08/2020   08:37:48         2020    SP         70734
# 3        01/08/2020   08:37:48         2020    SP         70734
# 4        01/08/2020   08:37:48         2020    SP         70734
# ...             ...        ...          ...   ...           ...
# 4248331  01/08/2020   08:37:48         2020    SP         72451
# 4248332  01/08/2020   08:37:48         2020    SP         72451
# 4248333  01/08/2020   08:37:48         2020    SP         72451
# 4248334  01/08/2020   08:37:48         2020    SP         72451
# 4248335  01/08/2020   08:37:48         2020    SP         72451
#
#                  NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 0        SÃO BENTO DO SAPUCAÍ                     0        Sem biometria
# ...

# %%
pd.DataFrame(dados_sp['DS_ESTADO_CIVIL'])
# Out:
#         DS_ESTADO_CIVIL
# 0                CASADO
# 1                CASADO
# 2                CASADO
# 3                CASADO
# 4                CASADO
# ...                 ...
# 4248331          CASADO
# 4248332          CASADO
# 4248333          CASADO
# 4248334          CASADO
# 4248335          CASADO
#
# [639502 rows x 1 columns]

# %%
estadocivil = list(dados_sp['HH_GERACAO'].drop_duplicates())

# %%
estadocivil
# Out:
# ['08:37:48']

# %%
dados_sp['DS_ESTADO_CIVIL'].info
# Out:
# <bound method Series.info of 0          CASADO
# 1          CASADO
# 2          CASADO
# 3          CASADO
# 4          CASADO
#             ...
# 4248331    CASADO
# 4248332    CASADO
# 4248333    CASADO
# 4248334    CASADO
# 4248335    CASADO
# Name: DS_ESTADO_CIVIL, Length: 639502, dtype: object>

# %%
A = dados_sp.shape[0]

# %%
A
# Out:
# 639502

# %%
coluna_para_deletar = 'ANO_ELEICAO'
df = dados_sp.drop(columns=[coluna_para_deletar])

# %%
df.head()
# Out:
#    DT_GERACAO HH_GERACAO SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  \
# 0  01/08/2020   08:37:48    SP         70734  SÃO BENTO DO SAPUCAÍ
# 1  01/08/2020   08:37:48    SP         70734  SÃO BENTO DO SAPUCAÍ
# 2  01/08/2020   08:37:48    SP         70734  SÃO BENTO DO SAPUCAÍ
# 3  01/08/2020   08:37:48    SP         70734  SÃO BENTO DO SAPUCAÍ
# 4  01/08/2020   08:37:48    SP         70734  SÃO BENTO DO SAPUCAÍ
#
#    CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  NR_ZONA  CD_GENERO DS_GENERO  \
# 0                     0        Sem biometria      314          4  FEMININO
# 1                     0        Sem biometria      314          4  FEMININO
# 2                     0        Sem biometria      314          4  FEMININO
# 3                     0        Sem biometria      314          4  FEMININO
# 4                     0        Sem biometria      314          4  FEMININO
#
#    CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# 0                3          CASADO             7074
# ...

# %%
df = df.drop(columns=['DS_MUN_SIT_BIOMETRIA'])

# %%
df = df.drop(columns=['CD_MUN_SIT_BIOMETRIA'])

# %%
df = df.drop(columns=['HH_GERACAO'])

# %%
df.head()
# Out:
#   SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_ZONA  CD_GENERO DS_GENERO  \
# 0    SP         70734  SÃO BENTO DO SAPUCAÍ      314          4  FEMININO
# 1    SP         70734  SÃO BENTO DO SAPUCAÍ      314          4  FEMININO
# 2    SP         70734  SÃO BENTO DO SAPUCAÍ      314          4  FEMININO
# 3    SP         70734  SÃO BENTO DO SAPUCAÍ      314          4  FEMININO
# 4    SP         70734  SÃO BENTO DO SAPUCAÍ      314          4  FEMININO
#
#    CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# 0                3          CASADO             7074
# 1                3          CASADO             7074
# 2                3          CASADO             7074
# 3                3          CASADO             7074
# 4                3          CASADO             7074
#
#                   DS_FAIXA_ETARIA  CD_GRAU_ESCOLARIDADE  \
# 0  70 a 74 anos                                       3
# 1  70 a 74 anos                                       4
# ...

# %%
df
# Out:
#         SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_ZONA  CD_GENERO  \
# 0          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 1          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 2          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 3          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 4          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# ...       ...           ...                   ...      ...        ...
# 4248331    SP         72451           VOTUPORANGA      147          2
# 4248332    SP         72451           VOTUPORANGA      147          2
# 4248333    SP         72451           VOTUPORANGA      147          2
# 4248334    SP         72451           VOTUPORANGA      147          2
# 4248335    SP         72451           VOTUPORANGA      147          2
#
#          DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# ...

# %%
df.to_csv('perfil_eleitorado_2020/eleitorado2020_tratado', sep = ',')

# %%
teste = list(dados['SG_UF'].drop_duplicates())

# %%
teste
# Out:
# ['SP',
#  'BA',
#  'MS',
#  'MG',
#  'PR',
#  'MA',
#  'GO',
#  'AL',
#  'MT',
#  'PB',
#  'TO',
#  'PA',
#  'PE',
#  'PI',
#  'ES',
#  'CE',
#  'RJ',
#  'RS',
#  'SC',
#  'RO',
#  'RN',
#  'SE',
#  'RR',
#  'AC',
#  'AM',
#  'AP']
